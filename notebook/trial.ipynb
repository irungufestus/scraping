# %%
import os
from pathlib import Path

# %%
# %pwd

# %%
os.chdir('../')

# %%
# %pwd
# Out:
# 'd:\\scraping\\notebook'

# %%
import os
import sys
import pandas as pd
import requests
import urllib.request
from urllib.error import URLError, HTTPError, ContentTooShortError
from bs4 import BeautifulSoup
from src.exception import CustomException
import logging
import time

# %%
from dataclasses import  dataclass

# %%
@dataclass
class DataIngestionConfig:
    raw_data_path:str=os.path.join('artifacts','books.csv')

# %%
class DataIngestion:
    def __init__(self):
        self.ingestionconfig=DataIngestionConfig()
        
    def initiate_data_ingestion(self):

        try:
            logging.info("Entered the get_data_from_url method of Data ingestion class")
            source_url = f"https://books.toscrape.com/catalogue/page-{i}.html"
            
            os.makedirs(os.path.dirname(self.ingestionconfig.test_data_path),exist_ok=True)
            def process_url(source_link, text):
                logging.info(f'Extracting links from {source_link}')
      
                books = []
                for i in range(1,5):
                    response = requests.get(source_url)
                    response = response.content
                    soup = BeautifulSoup(response, 'html.parser')
                    ol = soup.find('ol')
                    articles = ol.find_all('article', class_='product_pod')
                    for article in articles:
                        image = article.find('img')
                        title = image.attrs['alt']
                        starTag = article.find('p')
                        star = starTag['class'][1]
                        price = article.find('p', class_='price_color').text
                        price = float(price[1:])
                        books.append([title, star, price])
                
                    df = pd.DataFrame(books, columns=['Title', 'Star Rating', 'Price'])
                    df.to_csv(self.ingestionconfig.raw_data_path,index=False,header=True)
                    
               
            
            
            logging.info("Exited the get_data_from_gcloud method of Data ingestion class")
            return (self.ingestionconfig.raw_data_path)
        except Exception as e:
            raise e
    def download_images(self, destination_folder='raw_data/right_move_scraper/scraped_images'):
        '''A method that utilises the links stored under the 'Image' key of properties_dict_list
        and downloads the corresponding images into local directory'''
        if not os.path.exists(destination_folder):
            os.makedirs(destination_folder)

        for index, dict in enumerate(self.properties_dict_list):
            index += 1
            
            image_name = f'{self.date}_{self.current_time}_image_{str(index)}.jpeg'
            image_path = os.path.join(destination_folder, image_name)
            image_url = dict['Image']

            img_data = requests.get(image_url)
            with open(image_path, 'wb') as handler:       
                handler.write(img_data.content)
        
    def save_data_to_json(self, destination_folder='raw_data/right_move_scraper/data'):
        '''A method that converts properties_dict_list into a .json file and stores it into dedicated directories'''
        if not os.path.exists(destination_folder):
            os.makedirs(destination_folder)

        file_name = 'data.json'
        folder_path = os.path.join(destination_folder, file_name)
        
        with open(folder_path, 'w', encoding='utf-8') as output:
            json.dump(self.properties_dict_list, output, ensure_ascii=False, indent=4)

# %%
def get_data_from_url(self) -> None:
    try:
        logging.info("Entered the get_data_from_url method of Data ingestion class")

        os.makedirs(self.data_ingestion_config.DATA_INGESTION_ARTIFACTS_DIR, exist_ok=True)

        self.gcloud.sync_folder_from_gcloud(self.data_ingestion_config.BUCKET_NAME,
                                            self.data_ingestion_config.ZIP_FILE_NAME,
                                            self.data_ingestion_config.DATA_INGESTION_ARTIFACTS_DIR,
                                            )

        logging.info("Exited the get_data_from_gcloud method of Data ingestion class")

    except Exception as e:
        raise e

# %%
def image_download(url,soup_dir):
    try:
        os.mkdir(os.path.join(os.getcwd(),soup_dir),exist_ok=True)
    except Exception as e:
            raise CustomException(e, sys) from e
        
    os.chdir(os.path.join(os.getcwd(),soup_dir))
    r=requests.get(url)
    soup=BeautifulSoup(r.text,'html.parser')
    images=soup.find_all('img')
    for image in images:
        name=image['alt']
        link=image['src']
        with open(name.replace(' ', '-').replace('/', '') + '.jpg', 'wb') as f:
            #with open(name+'.jpg','wb') as f:
            im=requests.get(link)
            f.write(im.content)
            print('writing',name)
image_download("https://books.toscrape.com/","soup_dir")
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File c:\Users\optoswitch\anaconda3\envs\scrap\lib\site-packages\urllib3\connection.py:200, in HTTPConnection._new_conn(self)
#     199 try:
# --> 200     sock = connection.create_connection(
#     201         (self._dns_host, self.port),
#     202         self.timeout,
#     203         source_address=self.source_address,
#     204         socket_options=self.socket_options,
#     205     )
#     206 except socket.gaierror as e:
#
# File c:\Users\optoswitch\anaconda3\envs\scrap\lib\site-packages\urllib3\util\connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61     af, socktype, proto, canonname, sa = res
#
# ...

# %%
import pandas as pd

def imagedown(url,test_data_path):
  try:
    os.makedirs(os.path.join(os.getcwd(),test_data_path),exist_ok=True)
  except:
    pass 
  os.chdir(os.path.join(os.getcwd(),test_data_path))
  pages=[]
  prices=[]
  rating=[]
  title=[]
  url=[]
  
  books = []
  

  for i in range(1,-1):
    """loop  through required  pages  append  the page url accordingly
    
    Keyword arguments:
    argument -- description
    Return: return_description
    """
  
    url = ("https://books.toscrape.com/catalogue/category/books/fiction_{i}/index.html".format(i))
    pages.append(url)
    for item in pages:
      page = requests.get(item)
      soup = BeautifulSoup(page.text, 'html.parser')
      print(soup.prettify())
      
      ol = soup.find('ol')
      articles = ol.find_all('article', class_='product_pod')
      for article in articles:
        image = article.find('img')
        title = image.attrs['alt']
        starTag = article.find('p')
        star = starTag['class'][1]
        price = article.find('p', class_='price_color').text
        price = float(price[1:])
        books.append([title, star, price])
      
    df = pd.DataFrame(books, columns=['Title', 'Star Rating', 'Price'])
    df.to_csv('books.csv')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js zsg-theme-modernized null" itemscope="" itemtype="http://schema.org/Organization" lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#" xmlns:product="http://ogp.me/ns/product#">
#  <head>
#   <link href="https://fonts.googleapis.com/css?family=Open+Sans:400,600,700&amp;display=swap" rel="stylesheet"/>
#   <style type="text/css">
# ...

# %%
ol = soup.find('ol')
      articles = ol.find_all('article', class_='product_pod')
    for article in articles:
      image = article.find('img')
      title = image.attrs['alt']
      starTag = article.find('p')
      star = starTag['class'][1]
      price = article.find('p', class_='price_color').text
      price = float(price[1:])
      books.append([title, star, price])
    
  df = pd.DataFrame(books, columns=['Title', 'Star Rating', 'Price'])
  df.to_csv('books.csv')

# %%
# Out:
# <!DOCTYPE html>
# <html class="no-js zsg-theme-modernized null" itemscope="" itemtype="http://schema.org/Organization" lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#" xmlns:product="http://ogp.me/ns/product#">
# <head>
# ...

# %%
df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 df.shape
#
# NameError: name 'df' is not defined

# %%
df.head
# Out:
# <bound method NDFrame.head of                                                 Title Star Rating  Price
# 0            The Nameless City (The Nameless City #1)        Four  38.16
# 1   The Murder That Never Was (Forensic Instincts #5)       Three  54.11
# 2   The Most Perfect Thing: Inside (and Outside) a...        Four  42.96
# 3   The Mindfulness and Acceptance Workbook for An...        Four  23.89
# 4   The Life-Changing Magic of Tidying Up: The Jap...       Three  16.77
# ..                                                ...         ...    ...
# 75                                           Security         Two  39.25
# 76      Saga, Volume 6 (Saga (Collected Editions) #6)       Three  25.02
# 77      Saga, Volume 5 (Saga (Collected Editions) #5)         Two  51.04
# 78  Reskilling America: Learning to Labor in the T...         Two  19.83
# 79  Rat Queens, Vol. 3: Demons (Rat Queens (Collec...       Three  50.40
#
# [80 rows x 3 columns]>

# %%
def imagedown(url, folder):
    try:
        os.mkdir(os.path.join(os.getcwd(), folder))
    except:
        pass
    os.chdir(os.path.join(os.getcwd(), folder))
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')
    images = soup.find_all('img')
    for image in images:
        name = image['alt']
        link = image['src']
        with open(name.replace(' ', '-').replace('/', '') + '.jpg', 'wb') as f:
            im = requests.get(link)
            f.write(im.content)
            print('Writing: ', name)
